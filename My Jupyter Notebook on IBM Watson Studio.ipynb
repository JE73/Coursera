# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Jonas Ekberg__<br>
# Technical Consultant

# %% [markdown]
# _I am interested in data science because I think it is fun and interesting and I want to make a slight career shift._

# %% [markdown]
# My code is calculating 4 x 2.

# %%
4*2
# Out:
# 8

# %% [markdown]
# The answer is, as you see above, not ~~12~~, but 8.<br>
#
# __---__
#
# <br>
# Down below you see the first three prime numbers in a numbered list.
# 1. 2
# 2. 3
# 3. 5<br>
#
# And finally my favorite foods:
#
# |Category|Favorite food|
# |--------|-------------|
# |Breaksfast|Porridge|
# |Lunch|Pasta bolognese|
# |Dinner|Perisian kebab|
